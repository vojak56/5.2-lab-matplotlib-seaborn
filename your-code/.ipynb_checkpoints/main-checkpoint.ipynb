# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
# Your Code Here
import pylab as plt
# import matplotlib.pyplot as plt

plt.rcParams['figure.figsize']=(15, 8)   # tamaño por defecto, decenas de pixeles

import seaborn as sns
import pandas as pd

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
pd.set_option('display.max_columns', None)
df=pd.read_csv(r'../data/Fitbit2.csv')

# %%
df
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
data = df.groupby("Months_encoded").Steps.mean()

# %%
data
# Out:
# Months_encoded
# 1      9892.064516
# 2      8922.866667
# 3     10312.935484
# 4     13079.033333
# 5     10620.096774
# 6     12536.166667
# 7      9193.322581
# 8     11584.774194
# 9      9191.333333
# 10     8272.451613
# 11     9467.466667
# 12     8470.064516
# Name: Steps, dtype: float64

# %%
data.plot()
# Out:
# <AxesSubplot:xlabel='Months_encoded'>

# %%
# AVERAGE STEPS BY WORK_OR_WEEKEND
# your code here
data1 = df.groupby("Work_or_Weekend").Steps.mean()

# %%
data1.plot.bar()
# Out:
# <AxesSubplot:xlabel='Work_or_Weekend'>

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
def plot(i):
    fig, ax=plt.subplots(1, 3)
    for t,g in enumerate(i):
    
        sns.scatterplot(data=df,  
                        x=f'{g}',
                        y='Steps',
                       ax=ax[t]);

# %%
p = ["Minutes Lightly Active","Minutes Very Active","Minutes Sedentary"]
plot(p)

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
pd.set_option('display.max_columns', None)
df=pd.read_csv(r'../data/titanic.csv')

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
df.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
df.select_dtypes(include=["int64","float64"]).columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
# CATEGORICAL VARIABLES
# your code here
df.select_dtypes(include="object").columns
# Out:
# Index(['Name', 'Gender', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
plt.rcParams['figure.figsize']=(12, 6)

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
sns.histplot(x=df.Age,
             bins=80,          # nº de barras 
             kde=True,         # kde=kernel density estimation (la linea)
             element='step', 
             fill=False
            );

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
def plot(i):
    fig, ax=plt.subplots(1, 3)
    for t,g in enumerate(i):       
        sns.histplot(x=df.Age,
                     bins=g,          # nº de barras 
                     kde=True,         # kde=kernel density estimation (la linea)
                     element='step', 
                     fill=False,
                     ax=ax[t]
                    
                    );

# %%
plot([10,20,50])

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
The Precision of the distribution is affected by the bins
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
sns.histplot(x=df.Age,
             bins=80,          # nº de barras 
             kde=True,         # kde=kernel density estimation (la linea)
             element='step', 
             fill=False
            );

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
data1 = df.groupby("Gender").PassengerId.count()

# %%
data1.plot.bar()
# Out:
# <AxesSubplot:xlabel='Gender'>

# %%
# Method 2 - seaborn
# your code here
sns.countplot(x=df.Gender)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
sns.countplot(x=df.Pclass)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
df.Age.describe()[1:].plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.Age.describe()["25%"]
# Out:
# 22.0

# %%
"""
your comments here
Due to the numbers not being comparable no visualization style seems appropiate unless you remove the count
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
It tells us the big variance between highest and lowest age and that most og the passengers were under 40
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.histplot(x=df.Age,
                     bins=20,          # nº de barras 
                     kde=True,         # kde=kernel density estimation (la linea)
                     element='step', 
                     fill=False,
                     
                    
                    )
plt.axvline(x = df.Age.describe()["mean"], color = 'b', label = 'mean')
plt.axvline(x = df.Age.describe()["25%"], color = 'r', label = 'mean')
plt.axvline(x = df.Age.describe()["75%"], color = 'b' ,label = 'mean')
plt.axvline(x = df.Age.describe()["max"], color = 'r', label = 'mean')


;
# Out:
# ''

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
It shows us at which spot each major statistical distribution is within the age feature
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - seaborn

# %matplotlib inline
plt.figure(figsize=(14,8))
sns.regplot(x=df["Age"], y=df["Fare"])
plt.title('Age/Fare')
# Out:
# Text(0.5, 1.0, 'Age/Fare')

# %%
# Method 2 - seaborn
# your code here
plt.scatter(x=df["Age"], y=df["Fare"])

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
corr = df.corr(method='pearson')

# %%
corr
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.038354  0.025325 -0.055224  0.008942
# Survived       -0.005007  1.000000 -0.338481 -0.065376 -0.035322  0.081629
# Pclass         -0.038354 -0.338481  1.000000 -0.425965  0.060832  0.018322
# Age             0.025325 -0.065376 -0.425965  1.000000 -0.260706 -0.145488
# SibSp          -0.055224 -0.035322  0.060832 -0.260706  1.000000  0.373587
# Parch           0.008942  0.081629  0.018322 -0.145488  0.373587  1.000000
# Fare            0.031128  0.257307 -0.558683  0.171355  0.160349  0.221635
#
#                  Fare
# PassengerId  0.031128
# Survived     0.257307
# Pclass      -0.558683
# Age          0.171355
# SibSp        0.160349
# Parch        0.221635
# Fare         1.000000

# %%
sns.set(style='white') 
cmap=sns.diverging_palette(0, 10, as_cmap=True)   # paleta de colores


sns.heatmap(corr,
            cmap=cmap,
            vmax=1,
            vmin=-1,
            center=0,
            square=True,
            linewidth=0.5,
            cbar_kws={'shrink': 0.5},
            annot=True
           );

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
The Pclass and the Fare are strongly correlated
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# %matplotlib inline
plt.figure(figsize=(14,8))
sns.regplot(y=df["Age"], x=df["Pclass"])
plt.title('Age/Fare')
# Out:
# Text(0.5, 1.0, 'Age/Fare')

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
